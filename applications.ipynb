# %%
import pandas as pd

dfs=pd.DataFrame()

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls=["https://abit-poisk.org.ua/rate2024/direction/1330124/?page=1",
      "https://abit-poisk.org.ua/rate2023/direction/1191839",
      "https://abit-poisk.org.ua/rate2022/direction/999111",
      "https://abit-poisk.org.ua/rate2021/direction/869093",
      "https://abit-poisk.org.ua/rate2020/direction/742411",
      "https://abit-poisk.org.ua/rate2019/direction/555518",
      "https://abit-poisk.org.ua/rate2018/direction/442862",]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="КПІ"
        df["Cпеціалізація"]="Наука про дані та математичне моделювання"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls=["https://abit-poisk.org.ua/rate2024/direction/1330125","https://abit-poisk.org.ua/rate2023/direction/1191840",
      "https://abit-poisk.org.ua/rate2022/direction/999112","https://abit-poisk.org.ua/rate2021/direction/869093",
      "https://abit-poisk.org.ua/rate2020/direction/742411","https://abit-poisk.org.ua/rate2019/direction/555518"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="КПІ"
        df["Cпеціалізація"]=" Математичні методи криптографічного захисту інформації, Математичні методи моделювання, розпізнавання"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1350331","https://abit-poisk.org.ua/rate2023/direction/1219810",
       "https://abit-poisk.org.ua/rate2022/direction/1005232","https://abit-poisk.org.ua/rate2021/direction/883166",
       "https://abit-poisk.org.ua/rate2020/direction/764311"
       "https://abit-poisk.org.ua/rate2019/direction/611579","https://abit-poisk.org.ua/rate2018/direction/443904",
      ]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="КНУ"
        df["Cпеціалізація"]=" Математика та статистика / Прикладна математика"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1350331","https://abit-poisk.org.ua/rate2023/direction/1219810",
       "https://abit-poisk.org.ua/rate2022/direction/1005232","https://abit-poisk.org.ua/rate2021/direction/883166",
       "https://abit-poisk.org.ua/rate2020/direction/764311","https://abit-poisk.org.ua/rate2019/direction/611579","https://abit-poisk.org.ua/rate2018/direction/443904"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="Львівська політехніка"
        df["Cпеціалізація"]=" Математика та статистика / Прикладна математика"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1321114","https://abit-poisk.org.ua/rate2023/direction/1171788",
       "https://abit-poisk.org.ua/rate2022/direction/1005251","https://abit-poisk.org.ua/rate2021/direction/883189",
       "https://abit-poisk.org.ua/rate2020/direction/764351","https://abit-poisk.org.ua/rate2019/direction/591970",
       "https://abit-poisk.org.ua/rate2018/direction/444745"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="Львівська політехніка"
        df["Cпеціалізація"]=" Фінансовий інжиніринг"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1344683","https://abit-poisk.org.ua/rate2023/direction/1211600",
       "https://abit-poisk.org.ua/rate2022/direction/975914","https://abit-poisk.org.ua/rate2021/direction/829465",
       "https://abit-poisk.org.ua/rate2020/direction/690719","https://abit-poisk.org.ua/rate2019/direction/542312",
       "https://abit-poisk.org.ua/rate2018/direction/441973"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="ЛНУ ім. Івана Франка"
        df["Cпеціалізація"]="Математичне моделювання та комп’ютерна механіка"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1341313","https://abit-poisk.org.ua/rate2023/direction/1211008",
       "https://abit-poisk.org.ua/rate2022/direction/975424","https://abit-poisk.org.ua/rate2021/direction/828645",
       "https://abit-poisk.org.ua/rate2020/direction/689691","https://abit-poisk.org.ua/rate2019/direction/542313",
       "https://abit-poisk.org.ua/rate2018/direction/442016"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="ЛНУ ім. Івана Франка"
        df["Cпеціалізація"]="Математика та статистика / Прикладна математика"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1333138","https://abit-poisk.org.ua/rate2023/direction/1198731",
       "https://abit-poisk.org.ua/rate2022/direction/997720","https://abit-poisk.org.ua/rate2021/direction/865950",
       "https://abit-poisk.org.ua/rate2020/direction/737688","https://abit-poisk.org.ua/rate2019/direction/621336",
       "https://abit-poisk.org.ua/rate2018/direction/502588"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="НаУКМА"
        df["Cпеціалізація"]="Математика та статистика / Прикладна математика"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1340640","https://abit-poisk.org.ua/rate2023/direction/1212421",
       "https://abit-poisk.org.ua/rate2022/direction/977253","https://abit-poisk.org.ua/rate2021/direction/832259",
       "https://abit-poisk.org.ua/rate2020/direction/694775","https://abit-poisk.org.ua/rate2019/direction/570413",
       "https://abit-poisk.org.ua/rate2018/direction/442500"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="Каразінський університет"
        df["Cпеціалізація"]="Математика та статистика / Прикладна математика"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1418702","https://abit-poisk.org.ua/rate2023/direction/1256179",
       "https://abit-poisk.org.ua/rate2022/direction/1069026","https://abit-poisk.org.ua/rate2021/direction/925802",
       "https://abit-poisk.org.ua/rate2020/direction/766824"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="НТУ ХПІ"
        df["Cпеціалізація"]="Інтелектуальний аналіз даних"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1419304","https://abit-poisk.org.ua/rate2023/direction/1256619",
       "https://abit-poisk.org.ua/rate2022/direction/1068988","https://abit-poisk.org.ua/rate2021/direction/925802",
       "https://abit-poisk.org.ua/rate2020/direction/766824","https://abit-poisk.org.ua/rate2019/direction/618642",
       "https://abit-poisk.org.ua/rate2018/direction/440001"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="НТУ ХПІ"
        df["Cпеціалізація"]="Комп'ютерне та математичне моделювання"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1360325","https://abit-poisk.org.ua/rate2023/direction/1238202",
       "https://abit-poisk.org.ua/rate2022/direction/1069312","https://abit-poisk.org.ua/rate2021/direction/933404",
       "https://abit-poisk.org.ua/rate2020/direction/764078","https://abit-poisk.org.ua/rate2019/direction/606335",
       "https://abit-poisk.org.ua/rate2018/direction/480998"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="ОНПУ"
        df["Cпеціалізація"]="Математичне забезпечення комп’ютерних систем"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


urls = ["https://abit-poisk.org.ua/rate2024/direction/1342221","https://abit-poisk.org.ua/rate2023/direction/1211167",
       "https://abit-poisk.org.ua/rate2022/direction/975618","https://abit-poisk.org.ua/rate2021/direction/828962",
       "https://abit-poisk.org.ua/rate2020/direction/690100","https://abit-poisk.org.ua/rate2019/direction/552335",
       "https://abit-poisk.org.ua/rate2018/direction/459454"]
year=[2024,2023,2022,2021,2020,2019,2018]

for url,year in zip(urls,year):
    response = requests.get(url)


    if response.status_code == 200:
        
        soup = BeautifulSoup(response.content, 'html.parser')
        

        table = soup.find('table', {'class': 'table table-bordered table-hover'})  

   
        columns = []
        rows = []


        for th in table.find_all('th'):
            columns.append(th.text.strip())

        # Извлекаем строки таблицы
        for tr in table.find_all('tr')[1:]:  
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            rows.append(row)

        # Создаем DataFrame
        df = pd.DataFrame(rows, columns=columns)
        df["Рік"]=year
        df["Університет"]="ОНУ"
        df["Cпеціалізація"]="Математика та статистика / Прикладна математика"
        dfs=pd.concat([dfs,df])
    else:
        print(f"Ошибка доступа к странице, код: {response.status_code}")

# %%
dfs.to_csv("Вступники на прикладну математику 2018-2024.csv",index=False)

# %%
dfs.columns
# Out:
# Index(['№', 'ПІБ', 'П', 'Заг.бал', 'Статус', 'Складові заг. балу', 'Квота',
#        'ПВМ/ВЗ', 'Рік', 'Університет', 'Д'],
#       dtype='object')

# %%
import pandas as pd

# Данные из вашей строки
data = dfs[dfs.columns[5]]
# Разделяем данные на строки

result_list=[]
for data in dfs[dfs.columns[5]]:
    lines = data.split('\n')
    print(lines)
    first_score = lines[3]
    secend_score = lines[4]
    third_score = lines[5]
    try:
        fourth_score = lines[6]
    except IndexError as e:
        fourth_score = None

    # Извлекаем дополнительную информацию
    extra_info = lines[1:]
    extra_info = ' '.join(extra_info).strip().split(',')
    for i,info in enumerate(extra_info):
        print(i,info)
        print("////")
    # Создаем DataFrame
    result_list.append({
        'Перший критерій': first_score,
        'Другий кртитерій': secend_score,
        'Третій критерій': third_score,
        'Четвертий': fourth_score
    })

temp=pd.DataFrame(result_list)
# Out:
# ['131 176 144 150 ', '', '', 'Українська мова: 131', 'Математика: 176', 'Історія України: 144', 'Іноземна мова: 150']
# 0 Українська мова: 131 Математика: 176 Історія України: 144 Іноземна мова: 150
# ////
# ['125 149 134 ', '', '', 'Українська мова: 125', 'Математика: 149', 'Історія України: 134']
# 0 Українська мова: 125 Математика: 149 Історія України: 134
# ////
# ['183 200 194 200 ', '', '', 'Українська мова: 183', 'Математика: 200', 'Історія України: 194', 'Фізика: 200']
# 0 Українська мова: 183 Математика: 200 Історія України: 194 Фізика: 200
# ////
# ['186 194 188 194 ', '', '', 'Українська мова: 186', 'Математика: 194', 'Історія України: 188', 'Фізика: 194']
# 0 Українська мова: 186 Математика: 194 Історія України: 188 Фізика: 194
# ////
# ['187 192 186 ', '', '', 'Українська мова: 187', 'Математика: 192', 'Історія України: 186']
# 0 Українська мова: 187 Математика: 192 Історія України: 186
# ////
# ...

# %%
temp
# Out:
#                                Перший критерій       Другий кртитерій  \
# 0                         Українська мова: 131        Математика: 176
# 1                         Українська мова: 125        Математика: 149
# 2                         Українська мова: 183        Математика: 200
# 3                         Українська мова: 186        Математика: 194
# 4                         Українська мова: 187        Математика: 192
# ...                                        ...                    ...
# 1395  Українська мова та література (ЗНО): 193  Математика (ЗНО): 189
# 1396  Українська мова та література (ЗНО): 191  Математика (ЗНО): 192
# 1397  Українська мова та література (ЗНО): 192  Математика (ЗНО): 188
# 1398  Українська мова та література (ЗНО): 194      Фізика (ЗНО): 180
# 1399  Українська мова та література (ЗНО): 196  Математика (ЗНО): 189
#
#                Третій критерій                                Четвертий
# ...
